# %%
# !pip install tensorflow==2.8
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.8
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.0%2Bzzzcolab20220506162203-cp37-cp37m-linux_x86_64.whl (668.3 MB)
#      |████████████████████████████████| 668.3 MB 16 kB/s
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.12)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.26.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (14.0.6)
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 12.1 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.21.6)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (4.1.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (3.17.3)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 57.0 MB/s
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.1.0)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 55.7 MB/s
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.47.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.14.1)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (57.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow==2.8) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.0)
# Installing collected packages: tf-estimator-nightly, tensorboard, keras, tensorflow
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.1
#     Uninstalling tensorflow-2.9.1:
#       Successfully uninstalled tensorflow-2.9.1
# Successfully installed keras-2.8.0 tensorboard-2.8.0 tensorflow-2.8.0+zzzcolab20220506162203 tf-estimator-nightly-2.8.0.dev2021122109
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 18 not upgraded.
# Need to get 430 MB of archives.
# After this operation, 3,139 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.1.0.77-1+cuda11.2 [430 MB]
# Fetched 430 MB in 7s (59.0 MB/s)
# (Reading database ... 155676 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155654 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.1.0.77-1+cuda11.2_amd64.deb ...
# Unpacking libcudnn8 (8.1.0.77-1+cuda11.2) over (8.0.5.39-1+cuda11.1) ...
# Setting up libcudnn8 (8.1.0.77-1+cuda11.2) ...

# %%
import os
import cv2
import numpy as np
from glob import glob
from scipy.io import loadmat
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import backend as K
from keras.utils import io_utils
from tensorflow.python.platform import tf_logging as logging
from google.colab import drive

drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/collage/segmentation')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = "/content/drive/MyDrive/Colab Notebooks/collage/segmentation/data/rawdata/humanparsing"
train_num = 30
val_num = 10

all_images = sorted(glob(os.path.join(DATA_DIR, "val/Images/*")))
all_masks = sorted(glob(os.path.join(DATA_DIR, "val/Human/*")))

train_images, train_masks = all_images[:train_num], all_masks[:train_num]
val_images, val_masks = all_images[train_num:train_num+val_num], all_masks[train_num:train_num+val_num]

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.17.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 12.8 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.17.1

# %%
IMAGE_SIZE = 512
BATCH_SIZE = 8
NUM_CLASSES = 1
import tensorflow_addons as tfa

def read_image(image_path, mask=False):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, channels=3)
  image.set_shape([None, None, 3])
  image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
  if not mask:
      image = image / 255
  return image

def load_data(image_list, mask_list):
  image = read_image(image_list)
  mask = read_image(mask_list, mask=True)
  return image, mask

def random_crop(input_image, real_image, size):
  stacked_image = tf.stack([input_image, real_image], axis=0)
  cropped_image = tf.image.random_crop(
      stacked_image, size=[2, size, size, 3])
  img,msk = cropped_image[0], cropped_image[1]
  return img,msk

def augment(input_image, input_mask):

  if tf.random.uniform(()) > 0.3:
      ratio = tf.random.uniform(shape=[],minval=400, maxval=440, dtype=tf.int32)
      input_image, input_mask = random_crop(input_image, input_mask, ratio)
      input_image = tf.image.resize(input_image, (IMAGE_SIZE, IMAGE_SIZE))
      input_mask = tf.image.resize(input_mask, (IMAGE_SIZE, IMAGE_SIZE))

  input_image = tf.image.random_brightness(input_image, 0.2)

  saturation_factor = tf.random.uniform((),0,2)
  input_image = tf.image.adjust_saturation(input_image, saturation_factor)

  if tf.random.uniform(()) > 0.5:
      input_image = tf.image.flip_left_right(input_image)
      input_mask = tf.image.flip_left_right(input_mask)

  rot_factor = tf.cast(tf.random.uniform(shape=[],minval=-6, maxval=6, dtype=tf.int32), tf.float32)
  angle = np.pi/(12*6) *rot_factor
  input_image = tfa.image.rotate(input_image, angle)
  input_mask = tfa.image.rotate(input_mask, angle)

  return input_image, input_mask

def cast_mask(input_image, input_mask):
  
  input_mask = tf.math.reduce_sum(input_mask, axis=2)
  input_mask = input_mask[..., tf.newaxis]
  input_mask = tf.cast(input_mask>0, dtype=tf.float32)
  return input_image,input_mask

def data_generator(image_list, mask_list, augument=True):
  dataset = tf.data.Dataset.from_tensor_slices((image_list, mask_list))
  dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
  if augument:
    dataset = dataset.map(augment)
  dataset = dataset.map(cast_mask)

  dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
  return dataset

train_dataset = data_generator(train_images, train_masks)
print("Train Dataset:", train_dataset)

val_dataset = data_generator(val_images, val_masks, augument=False)
print("Validation Dataset:", val_dataset)
# Out:
# Train Dataset: <BatchDataset element_spec=(TensorSpec(shape=(8, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(8, 512, 512, 1), dtype=tf.float32, name=None))>
# Validation Dataset: <BatchDataset element_spec=(TensorSpec(shape=(8, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(8, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
_, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

idx = 9
img = read_image(train_images[idx])
msk = read_image(train_masks[idx], mask=True)

augmented_img, augmented_msk = augment(img,msk)


# axes[0][0].imshow(np.squeeze(np.where(np.sum(msk, axis=2)>0, 1,0)))
axes[0][0].imshow(np.squeeze(msk))
axes[0][1].imshow(img)
axes[1][0].imshow(np.squeeze(augmented_msk))
axes[1][1].imshow(augmented_img)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def convolution_block(
    block_input,
    num_filters=256,
    kernel_size=3,
    dilation_rate=1,
    padding="same",
    use_bias=False,
):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        dilation_rate=dilation_rate,
        padding="same",
        use_bias=use_bias,
        kernel_initializer=keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return tf.nn.relu(x)


def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[-3], dims[-2]))(dspp_input)
    x = convolution_block(x, kernel_size=1, use_bias=True)
    out_pool = layers.UpSampling2D(
        size=(dims[-3] // x.shape[1], dims[-2] // x.shape[2]), interpolation="bilinear",
    )(x)

    out_1 = convolution_block(dspp_input, kernel_size=1, dilation_rate=1)
    out_6 = convolution_block(dspp_input, kernel_size=3, dilation_rate=6)
    out_12 = convolution_block(dspp_input, kernel_size=3, dilation_rate=12)
    out_18 = convolution_block(dspp_input, kernel_size=3, dilation_rate=18)

    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_6, out_12, out_18])
    output = convolution_block(x, kernel_size=1)
    return output

def SE_block(input_tensor, reduction_ratio=8):
    ch_input = K.int_shape(input_tensor)[-1]
    ch_reduced = ch_input//reduction_ratio  
    # Squeeze
    x = layers.GlobalAveragePooling2D()(input_tensor) # Eqn.2
    # Excitation
    x = layers.Dense(ch_reduced, kernel_initializer='he_normal', activation='relu', use_bias=False)(x) # Eqn.3
    x = layers.Dense(ch_input, kernel_initializer='he_normal', activation='sigmoid', use_bias=False)(x) # Eqn.3 
    x = layers.Reshape((1, 1, ch_input))(x)
    x = layers.Multiply()([input_tensor, x])
    
    return x

# %%
def DeeplabV3Plus(image_size, num_classes, find_tunebackbone=False):
    model_input = keras.Input(shape=(image_size, image_size, 3))
    effiucientnetV2M = tf.keras.applications.EfficientNetV2M(
        weights="imagenet", include_top=False, input_tensor=model_input
    )
    if not find_tunebackbone:
      for layer in effiucientnetV2M.layers:
        if '_bn' not in layer.name:
          layer.trainable = False
    x = effiucientnetV2M.get_layer("block6a_expand_activation").output
    x = DilatedSpatialPyramidPooling(x)
    # x = SE_block(x)
    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = effiucientnetV2M.get_layer("block2e_add").output
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)

    x = layers.Concatenate(axis=-1)([input_a, input_b])
    # x = SE_block(x)
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same", activation='sigmoid')(x)
    return keras.Model(inputs=model_input, outputs=model_output)

# %%
class unfreeze_layers_reduce_lr(tf.keras.callbacks.ReduceLROnPlateau):

  def __init__(self,
               monitor='val_loss',
               factor=0.1,
               patience=10,
               verbose=0,
               mode='auto',
               min_delta=1e-4,
               cooldown=0,
               min_lr=0,
               freezed=False,
               **kwargs):
      super().__init__(monitor, factor, patience, verbose, mode, min_delta, cooldown, min_lr)
      self.freezed = False


  def on_epoch_end(self, epoch, logs=None):
    logs = logs or {}
    logs['lr'] = K.get_value(self.model.optimizer.lr)
    current = logs.get(self.monitor)
    if current is None:
      logging.warning('Learning rate reduction is conditioned on metric `%s` '
                      'which is not available. Available metrics are: %s',
                      self.monitor, ','.join(list(logs.keys())))
    else:
      if self.in_cooldown():
        self.cooldown_counter -= 1
        self.wait = 0

      if self.monitor_op(current, self.best):
        self.best = current
        self.wait = 0

      elif not self.in_cooldown():
        self.wait += 1
        if self.wait >= self.patience:
          
          if not self.freezed:
            for layer in self.model.layers:
                      layer.trainable = True
            self.freezed=True
            old_lr = K.get_value(self.model.optimizer.lr)
            new_lr = old_lr * 0.1
            K.set_value(self.model.optimizer.lr, new_lr)
            io_utils.print_msg(
                    f'\nEpoch {epoch +1}: '
                    f'Unfreezing backbone layers and reducing learning rate to {new_lr}')
            self.cooldown_counter = self.cooldown
            self.wait = 0

          else:
            old_lr = K.get_value(self.model.optimizer.lr)
            if old_lr > np.float32(self.min_lr):
              new_lr = old_lr * self.factor
              new_lr = max(new_lr, self.min_lr)
              K.set_value(self.model.optimizer.lr, new_lr)
              if self.verbose > 0:
                io_utils.print_msg(
                    f'\nEpoch {epoch +1}: '
                    f'ReduceLROnPlateau reducing learning rate to {new_lr}.')
              self.cooldown_counter = self.cooldown
              self.wait = 0

class CustomSaver(keras.callbacks.Callback):
  def __init__(self, save_path, save_name, frequency):
    self.save_path = save_path
    self.save_name = save_name
    self.frequency = frequency

  def on_epoch_end(self, epoch, logs={}):
      if (epoch+1) % self.frequency == 0 :
          name = self.save_path + self.save_name + f'{epoch+1:03d}.h5'
          self.model.save(name)
          io_utils.print_msg(
                    f'\nEpoch {epoch + 1}:'
                    f'saving model to {name}')

model_path, model_name = './model_weight/callback_test/', 'test_weight_epoch_'
model_path_best = './model_weight/callback_test/test_weight_best.h5'
csv_name = './model_weight/callback_test/test_weight.csv'

custom_saver = CustomSaver(model_path, model_name ,frequency=10)
reduce_lr = unfreeze_layers_reduce_lr(monitor='val_loss', factor=0.5, patience=2, verbose=1, mode='min', min_delta=1e-4, cooldown=0, min_lr=0,)
save_best = tf.keras.callbacks.ModelCheckpoint(model_path_best, monitor='val_loss', verbose=0, save_best_only=True)
write_log = tf.keras.callbacks.CSVLogger(csv_name, separator=',', append=True)

cb_list = [custom_saver, reduce_lr, save_best, write_log]

# %%
model = DeeplabV3Plus(image_size=IMAGE_SIZE, num_classes=NUM_CLASSES)

loss = keras.losses.BinaryCrossentropy()
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.01),
    loss=loss,
    metrics=["accuracy",tf.keras.metrics.BinaryIoU()],
  )
# model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214204416/214201816 [==============================] - 1s 0us/step
# 214212608/214201816 [==============================] - 1s 0us/step

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    callbacks=cb_list,
                    epochs=100)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 35s 5s/step - loss: 1.7034 - accuracy: 0.5446 - binary_io_u: 0.3697 - val_loss: 630.2427 - val_accuracy: 0.6155 - val_binary_io_u: 0.4441 - lr: 0.0100
# Epoch 2/100
# 3/3 [==============================] - 3s 797ms/step - loss: 0.8979 - accuracy: 0.7045 - binary_io_u: 0.5435 - val_loss: 947.0352 - val_accuracy: 0.5125 - val_binary_io_u: 0.2746 - lr: 0.0100
# Epoch 3/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.5704 - accuracy: 0.7208 - binary_io_u: 0.5603 - val_loss: 414.3644 - val_accuracy: 0.5294 - val_binary_io_u: 0.2647 - lr: 0.0100
# Epoch 4/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.5572 - accuracy: 0.6017 - binary_io_u: 0.3635 - val_loss: 151.4518 - val_accuracy: 0.5134 - val_binary_io_u: 0.2683 - lr: 0.0100
# Epoch 5/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.5069 - accuracy: 0.7715 - binary_io_u: 0.6140 - val_loss: 49.4969 - val_accuracy: 0.5456 - val_binary_io_u: 0.3379 - lr: 0.0100
# Epoch 6/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4600 - accuracy: 0.7918 - binary_io_u: 0.6538 - val_loss: 25.9719 - val_accuracy: 0.6122 - val_binary_io_u: 0.4286 - lr: 0.0100
# Epoch 7/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.4234 - accuracy: 0.8116 - binary_io_u: 0.6828 - val_loss: 17.4091 - val_accuracy: 0.6425 - val_binary_io_u: 0.4651 - lr: 0.0100
# Epoch 8/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4117 - accuracy: 0.8243 - binary_io_u: 0.7001 - val_loss: 12.9534 - val_accuracy: 0.6712 - val_binary_io_u: 0.5026 - lr: 0.0100
# Epoch 9/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.3838 - accuracy: 0.8271 - binary_io_u: 0.7032 - val_loss: 9.8268 - val_accuracy: 0.6932 - val_binary_io_u: 0.5295 - lr: 0.0100
# Epoch 10/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.8467 - binary_io_u: 0.7305
# Epoch 10:saving model to ./model_weight/callback_test/test_weight_epoch_010.h5
# 3/3 [==============================] - 12s 6s/step - loss: 0.3380 - accuracy: 0.8467 - binary_io_u: 0.7305 - val_loss: 7.4921 - val_accuracy: 0.7003 - val_binary_io_u: 0.5363 - lr: 0.0100
# Epoch 11/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3253 - accuracy: 0.8568 - binary_io_u: 0.7458 - val_loss: 5.9374 - val_accuracy: 0.6930 - val_binary_io_u: 0.5233 - lr: 0.0100
# Epoch 12/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.3471 - accuracy: 0.8476 - binary_io_u: 0.7302 - val_loss: 4.7394 - val_accuracy: 0.7053 - val_binary_io_u: 0.5362 - lr: 0.0100
# Epoch 13/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2958 - accuracy: 0.8719 - binary_io_u: 0.7662 - val_loss: 3.6220 - val_accuracy: 0.7267 - val_binary_io_u: 0.5644 - lr: 0.0100
# Epoch 14/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2756 - accuracy: 0.8799 - binary_io_u: 0.7811 - val_loss: 2.7412 - val_accuracy: 0.7553 - val_binary_io_u: 0.6036 - lr: 0.0100
# Epoch 15/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2633 - accuracy: 0.8871 - binary_io_u: 0.7945 - val_loss: 2.0819 - val_accuracy: 0.7920 - val_binary_io_u: 0.6547 - lr: 0.0100
# Epoch 16/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2494 - accuracy: 0.8951 - binary_io_u: 0.8072 - val_loss: 1.7063 - val_accuracy: 0.8150 - val_binary_io_u: 0.6876 - lr: 0.0100
# Epoch 17/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2556 - accuracy: 0.8924 - binary_io_u: 0.8027 - val_loss: 1.5221 - val_accuracy: 0.8276 - val_binary_io_u: 0.7058 - lr: 0.0100
# Epoch 18/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2357 - accuracy: 0.9045 - binary_io_u: 0.8241 - val_loss: 1.3671 - val_accuracy: 0.8380 - val_binary_io_u: 0.7212 - lr: 0.0100
# Epoch 19/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2605 - accuracy: 0.8900 - binary_io_u: 0.7991 - val_loss: 1.2256 - val_accuracy: 0.8532 - val_binary_io_u: 0.7440 - lr: 0.0100
# Epoch 20/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9099 - binary_io_u: 0.8317
# Epoch 20:saving model to ./model_weight/callback_test/test_weight_epoch_020.h5
# 3/3 [==============================] - 9s 4s/step - loss: 0.2144 - accuracy: 0.9099 - binary_io_u: 0.8317 - val_loss: 1.0902 - val_accuracy: 0.8623 - val_binary_io_u: 0.7578 - lr: 0.0100
# Epoch 21/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2029 - accuracy: 0.9174 - binary_io_u: 0.8444 - val_loss: 1.0831 - val_accuracy: 0.8646 - val_binary_io_u: 0.7613 - lr: 0.0100
# Epoch 22/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2169 - accuracy: 0.9086 - binary_io_u: 0.8298 - val_loss: 1.0147 - val_accuracy: 0.8687 - val_binary_io_u: 0.7675 - lr: 0.0100
# Epoch 23/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1788 - accuracy: 0.9267 - binary_io_u: 0.8604 - val_loss: 0.9915 - val_accuracy: 0.8651 - val_binary_io_u: 0.7618 - lr: 0.0100
# Epoch 24/100
# 3/3 [==============================] - 2s 712ms/step - loss: 0.1924 - accuracy: 0.9192 - binary_io_u: 0.8478 - val_loss: 0.9984 - val_accuracy: 0.8658 - val_binary_io_u: 0.7628 - lr: 0.0100
# Epoch 25/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1931 - accuracy: 0.9209 - binary_io_u: 0.8512 - val_loss: 0.9394 - val_accuracy: 0.8660 - val_binary_io_u: 0.7632 - lr: 0.0100
# Epoch 26/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2038 - accuracy: 0.9158 - binary_io_u: 0.8432 - val_loss: 0.8564 - val_accuracy: 0.8741 - val_binary_io_u: 0.7761 - lr: 0.0100
# Epoch 27/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1765 - accuracy: 0.9281 - binary_io_u: 0.8644 - val_loss: 0.8292 - val_accuracy: 0.8795 - val_binary_io_u: 0.7845 - lr: 0.0100
# Epoch 28/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1779 - accuracy: 0.9277 - binary_io_u: 0.8639 - val_loss: 0.8229 - val_accuracy: 0.8783 - val_binary_io_u: 0.7826 - lr: 0.0100
# Epoch 29/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1637 - accuracy: 0.9333 - binary_io_u: 0.8730 - val_loss: 0.7884 - val_accuracy: 0.8774 - val_binary_io_u: 0.7813 - lr: 0.0100
# Epoch 30/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9309 - binary_io_u: 0.8695
# Epoch 30:saving model to ./model_weight/callback_test/test_weight_epoch_030.h5
# 3/3 [==============================] - 9s 4s/step - loss: 0.1710 - accuracy: 0.9309 - binary_io_u: 0.8695 - val_loss: 0.6701 - val_accuracy: 0.8870 - val_binary_io_u: 0.7968 - lr: 0.0100
# Epoch 31/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1792 - accuracy: 0.9289 - binary_io_u: 0.8663 - val_loss: 0.6091 - val_accuracy: 0.8881 - val_binary_io_u: 0.7985 - lr: 0.0100
# Epoch 32/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1630 - accuracy: 0.9330 - binary_io_u: 0.8726 - val_loss: 0.5822 - val_accuracy: 0.8834 - val_binary_io_u: 0.7909 - lr: 0.0100
# Epoch 33/100
# 3/3 [==============================] - 4s 707ms/step - loss: 0.1628 - accuracy: 0.9341 - binary_io_u: 0.8750 - val_loss: 0.6067 - val_accuracy: 0.8648 - val_binary_io_u: 0.7613 - lr: 0.0100
# Epoch 34/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9363 - binary_io_u: 0.8789
# Epoch 34: Unfreezing backbone layers and reducing learning rate to 0.0009999999776482583
# 3/3 [==============================] - 2s 711ms/step - loss: 0.1616 - accuracy: 0.9363 - binary_io_u: 0.8789 - val_loss: 0.5839 - val_accuracy: 0.8622 - val_binary_io_u: 0.7571 - lr: 0.0100
# Epoch 35/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1509 - accuracy: 0.9382 - binary_io_u: 0.8821 - val_loss: 0.5194 - val_accuracy: 0.8764 - val_binary_io_u: 0.7797 - lr: 1.0000e-03
# Epoch 36/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1602 - accuracy: 0.9342 - binary_io_u: 0.8760 - val_loss: 0.4728 - val_accuracy: 0.8879 - val_binary_io_u: 0.7983 - lr: 1.0000e-03
# Epoch 37/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1522 - accuracy: 0.9379 - binary_io_u: 0.8813 - val_loss: 0.4635 - val_accuracy: 0.8912 - val_binary_io_u: 0.8036 - lr: 1.0000e-03
# Epoch 38/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1490 - accuracy: 0.9385 - binary_io_u: 0.8823 - val_loss: 0.4591 - val_accuracy: 0.8932 - val_binary_io_u: 0.8070 - lr: 1.0000e-03
# Epoch 39/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1488 - accuracy: 0.9378 - binary_io_u: 0.8818 - val_loss: 0.4391 - val_accuracy: 0.8985 - val_binary_io_u: 0.8157 - lr: 1.0000e-03
# Epoch 40/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9377 - binary_io_u: 0.8815
# Epoch 40:saving model to ./model_weight/callback_test/test_weight_epoch_040.h5
# 3/3 [==============================] - 11s 5s/step - loss: 0.1507 - accuracy: 0.9377 - binary_io_u: 0.8815 - val_loss: 0.4276 - val_accuracy: 0.9008 - val_binary_io_u: 0.8195 - lr: 1.0000e-03
# Epoch 41/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1506 - accuracy: 0.9392 - binary_io_u: 0.8837 - val_loss: 0.4220 - val_accuracy: 0.9027 - val_binary_io_u: 0.8226 - lr: 1.0000e-03
# Epoch 42/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1464 - accuracy: 0.9397 - binary_io_u: 0.8847 - val_loss: 0.4107 - val_accuracy: 0.9047 - val_binary_io_u: 0.8261 - lr: 1.0000e-03
# Epoch 43/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1480 - accuracy: 0.9395 - binary_io_u: 0.8841 - val_loss: 0.4044 - val_accuracy: 0.9062 - val_binary_io_u: 0.8284 - lr: 1.0000e-03
# Epoch 44/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1533 - accuracy: 0.9368 - binary_io_u: 0.8795 - val_loss: 0.3876 - val_accuracy: 0.9087 - val_binary_io_u: 0.8326 - lr: 1.0000e-03
# Epoch 45/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1442 - accuracy: 0.9407 - binary_io_u: 0.8863 - val_loss: 0.3794 - val_accuracy: 0.9095 - val_binary_io_u: 0.8340 - lr: 1.0000e-03
# Epoch 46/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1488 - accuracy: 0.9402 - binary_io_u: 0.8865 - val_loss: 0.3623 - val_accuracy: 0.9112 - val_binary_io_u: 0.8368 - lr: 1.0000e-03
# Epoch 47/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1453 - accuracy: 0.9407 - binary_io_u: 0.8866 - val_loss: 0.3511 - val_accuracy: 0.9122 - val_binary_io_u: 0.8385 - lr: 1.0000e-03
# Epoch 48/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1449 - accuracy: 0.9400 - binary_io_u: 0.8857 - val_loss: 0.3445 - val_accuracy: 0.9126 - val_binary_io_u: 0.8392 - lr: 1.0000e-03
# Epoch 49/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1565 - accuracy: 0.9364 - binary_io_u: 0.8790 - val_loss: 0.3362 - val_accuracy: 0.9134 - val_binary_io_u: 0.8407 - lr: 1.0000e-03
# Epoch 50/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9399 - binary_io_u: 0.8852
# Epoch 50:saving model to ./model_weight/callback_test/test_weight_epoch_050.h5
# 3/3 [==============================] - 9s 4s/step - loss: 0.1488 - accuracy: 0.9399 - binary_io_u: 0.8852 - val_loss: 0.3259 - val_accuracy: 0.9140 - val_binary_io_u: 0.8416 - lr: 1.0000e-03
# Epoch 51/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1453 - accuracy: 0.9410 - binary_io_u: 0.8875 - val_loss: 0.3151 - val_accuracy: 0.9150 - val_binary_io_u: 0.8433 - lr: 1.0000e-03
# Epoch 52/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1438 - accuracy: 0.9413 - binary_io_u: 0.8878 - val_loss: 0.3054 - val_accuracy: 0.9156 - val_binary_io_u: 0.8444 - lr: 1.0000e-03
# Epoch 53/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1410 - accuracy: 0.9441 - binary_io_u: 0.8931 - val_loss: 0.2975 - val_accuracy: 0.9160 - val_binary_io_u: 0.8450 - lr: 1.0000e-03
# Epoch 54/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1430 - accuracy: 0.9411 - binary_io_u: 0.8874 - val_loss: 0.2946 - val_accuracy: 0.9154 - val_binary_io_u: 0.8440 - lr: 1.0000e-03
# Epoch 55/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1509 - accuracy: 0.9392 - binary_io_u: 0.8834 - val_loss: 0.2941 - val_accuracy: 0.9158 - val_binary_io_u: 0.8447 - lr: 1.0000e-03
# Epoch 56/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1399 - accuracy: 0.9425 - binary_io_u: 0.8899 - val_loss: 0.2903 - val_accuracy: 0.9163 - val_binary_io_u: 0.8455 - lr: 1.0000e-03
# Epoch 57/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1500 - accuracy: 0.9379 - binary_io_u: 0.8816 - val_loss: 0.2864 - val_accuracy: 0.9162 - val_binary_io_u: 0.8454 - lr: 1.0000e-03
# Epoch 58/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1443 - accuracy: 0.9417 - binary_io_u: 0.8887 - val_loss: 0.2775 - val_accuracy: 0.9171 - val_binary_io_u: 0.8469 - lr: 1.0000e-03
# Epoch 59/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1511 - accuracy: 0.9381 - binary_io_u: 0.8817 - val_loss: 0.2749 - val_accuracy: 0.9170 - val_binary_io_u: 0.8466 - lr: 1.0000e-03
# Epoch 60/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9462 - binary_io_u: 0.8965
# Epoch 60:saving model to ./model_weight/callback_test/test_weight_epoch_060.h5
# 3/3 [==============================] - 11s 5s/step - loss: 0.1352 - accuracy: 0.9462 - binary_io_u: 0.8965 - val_loss: 0.2714 - val_accuracy: 0.9177 - val_binary_io_u: 0.8479 - lr: 1.0000e-03
# Epoch 61/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1433 - accuracy: 0.9418 - binary_io_u: 0.8881 - val_loss: 0.2665 - val_accuracy: 0.9180 - val_binary_io_u: 0.8484 - lr: 1.0000e-03
# Epoch 62/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1394 - accuracy: 0.9424 - binary_io_u: 0.8894 - val_loss: 0.2639 - val_accuracy: 0.9183 - val_binary_io_u: 0.8488 - lr: 1.0000e-03
# Epoch 63/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1548 - accuracy: 0.9363 - binary_io_u: 0.8786 - val_loss: 0.2635 - val_accuracy: 0.9185 - val_binary_io_u: 0.8492 - lr: 1.0000e-03
# Epoch 64/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1456 - accuracy: 0.9413 - binary_io_u: 0.8872 - val_loss: 0.2615 - val_accuracy: 0.9190 - val_binary_io_u: 0.8500 - lr: 1.0000e-03
# Epoch 65/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1432 - accuracy: 0.9417 - binary_io_u: 0.8883 - val_loss: 0.2605 - val_accuracy: 0.9191 - val_binary_io_u: 0.8501 - lr: 1.0000e-03
# Epoch 66/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1400 - accuracy: 0.9438 - binary_io_u: 0.8927 - val_loss: 0.2573 - val_accuracy: 0.9194 - val_binary_io_u: 0.8507 - lr: 1.0000e-03
# Epoch 67/100
# 3/3 [==============================] - 2s 711ms/step - loss: 0.1429 - accuracy: 0.9409 - binary_io_u: 0.8866 - val_loss: 0.2594 - val_accuracy: 0.9190 - val_binary_io_u: 0.8501 - lr: 1.0000e-03
# Epoch 68/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1405 - accuracy: 0.9425 - binary_io_u: 0.8898 - val_loss: 0.2563 - val_accuracy: 0.9194 - val_binary_io_u: 0.8507 - lr: 1.0000e-03
# Epoch 69/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1567 - accuracy: 0.9366 - binary_io_u: 0.8789 - val_loss: 0.2557 - val_accuracy: 0.9190 - val_binary_io_u: 0.8500 - lr: 1.0000e-03
# Epoch 70/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9394 - binary_io_u: 0.8846
# Epoch 70:saving model to ./model_weight/callback_test/test_weight_epoch_070.h5
# 3/3 [==============================] - 9s 4s/step - loss: 0.1482 - accuracy: 0.9394 - binary_io_u: 0.8846 - val_loss: 0.2516 - val_accuracy: 0.9193 - val_binary_io_u: 0.8504 - lr: 1.0000e-03
# Epoch 71/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1524 - accuracy: 0.9381 - binary_io_u: 0.8826 - val_loss: 0.2496 - val_accuracy: 0.9193 - val_binary_io_u: 0.8504 - lr: 1.0000e-03
# Epoch 72/100
# 3/3 [==============================] - 2s 711ms/step - loss: 0.1411 - accuracy: 0.9427 - binary_io_u: 0.8896 - val_loss: 0.2505 - val_accuracy: 0.9187 - val_binary_io_u: 0.8495 - lr: 1.0000e-03
# Epoch 73/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9435 - binary_io_u: 0.8911
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0004999999655410647.
# 3/3 [==============================] - 2s 713ms/step - loss: 0.1411 - accuracy: 0.9435 - binary_io_u: 0.8911 - val_loss: 0.2509 - val_accuracy: 0.9193 - val_binary_io_u: 0.8505 - lr: 1.0000e-03
# Epoch 74/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1299 - accuracy: 0.9483 - binary_io_u: 0.9007 - val_loss: 0.2474 - val_accuracy: 0.9197 - val_binary_io_u: 0.8511 - lr: 5.0000e-04
# Epoch 75/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1472 - accuracy: 0.9404 - binary_io_u: 0.8856 - val_loss: 0.2457 - val_accuracy: 0.9198 - val_binary_io_u: 0.8513 - lr: 5.0000e-04
# Epoch 76/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1322 - accuracy: 0.9463 - binary_io_u: 0.8960 - val_loss: 0.2442 - val_accuracy: 0.9199 - val_binary_io_u: 0.8515 - lr: 5.0000e-04
# Epoch 77/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1378 - accuracy: 0.9436 - binary_io_u: 0.8923 - val_loss: 0.2414 - val_accuracy: 0.9203 - val_binary_io_u: 0.8522 - lr: 5.0000e-04
# Epoch 78/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1372 - accuracy: 0.9458 - binary_io_u: 0.8958 - val_loss: 0.2385 - val_accuracy: 0.9204 - val_binary_io_u: 0.8524 - lr: 5.0000e-04
# Epoch 79/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1466 - accuracy: 0.9392 - binary_io_u: 0.8839 - val_loss: 0.2381 - val_accuracy: 0.9204 - val_binary_io_u: 0.8523 - lr: 5.0000e-04
# Epoch 80/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9429 - binary_io_u: 0.8903
# Epoch 80:saving model to ./model_weight/callback_test/test_weight_epoch_080.h5
# 3/3 [==============================] - 9s 4s/step - loss: 0.1392 - accuracy: 0.9429 - binary_io_u: 0.8903 - val_loss: 0.2381 - val_accuracy: 0.9201 - val_binary_io_u: 0.8519 - lr: 5.0000e-04
# Epoch 81/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1316 - accuracy: 0.9467 - binary_io_u: 0.8977 - val_loss: 0.2370 - val_accuracy: 0.9200 - val_binary_io_u: 0.8516 - lr: 5.0000e-04
# Epoch 82/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1453 - accuracy: 0.9402 - binary_io_u: 0.8858 - val_loss: 0.2363 - val_accuracy: 0.9204 - val_binary_io_u: 0.8524 - lr: 5.0000e-04
# Epoch 83/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1308 - accuracy: 0.9481 - binary_io_u: 0.9001 - val_loss: 0.2352 - val_accuracy: 0.9204 - val_binary_io_u: 0.8523 - lr: 5.0000e-04
# Epoch 84/100
# 3/3 [==============================] - 2s 707ms/step - loss: 0.1351 - accuracy: 0.9470 - binary_io_u: 0.8970 - val_loss: 0.2354 - val_accuracy: 0.9206 - val_binary_io_u: 0.8527 - lr: 5.0000e-04
# Epoch 85/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1358 - accuracy: 0.9442 - binary_io_u: 0.8932 - val_loss: 0.2337 - val_accuracy: 0.9206 - val_binary_io_u: 0.8527 - lr: 5.0000e-04
# Epoch 86/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1353 - accuracy: 0.9452 - binary_io_u: 0.8950 - val_loss: 0.2324 - val_accuracy: 0.9206 - val_binary_io_u: 0.8526 - lr: 5.0000e-04
# Epoch 87/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1366 - accuracy: 0.9442 - binary_io_u: 0.8929 - val_loss: 0.2316 - val_accuracy: 0.9205 - val_binary_io_u: 0.8525 - lr: 5.0000e-04
# Epoch 88/100
# 3/3 [==============================] - 2s 707ms/step - loss: 0.1373 - accuracy: 0.9441 - binary_io_u: 0.8931 - val_loss: 0.2322 - val_accuracy: 0.9203 - val_binary_io_u: 0.8522 - lr: 5.0000e-04
# Epoch 89/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9452 - binary_io_u: 0.8943
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.00024999998277053237.
# 3/3 [==============================] - 2s 710ms/step - loss: 0.1364 - accuracy: 0.9452 - binary_io_u: 0.8943 - val_loss: 0.2316 - val_accuracy: 0.9206 - val_binary_io_u: 0.8527 - lr: 5.0000e-04
# Epoch 90/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9449 - binary_io_u: 0.8937
# Epoch 90:saving model to ./model_weight/callback_test/test_weight_epoch_090.h5
# 3/3 [==============================] - 10s 5s/step - loss: 0.1400 - accuracy: 0.9449 - binary_io_u: 0.8937 - val_loss: 0.2315 - val_accuracy: 0.9209 - val_binary_io_u: 0.8532 - lr: 2.5000e-04
# Epoch 91/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1363 - accuracy: 0.9445 - binary_io_u: 0.8936 - val_loss: 0.2313 - val_accuracy: 0.9206 - val_binary_io_u: 0.8526 - lr: 2.5000e-04
# Epoch 92/100
# 3/3 [==============================] - 2s 712ms/step - loss: 0.1333 - accuracy: 0.9456 - binary_io_u: 0.8955 - val_loss: 0.2314 - val_accuracy: 0.9204 - val_binary_io_u: 0.8522 - lr: 2.5000e-04
# Epoch 93/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1332 - accuracy: 0.9471 - binary_io_u: 0.8980 - val_loss: 0.2309 - val_accuracy: 0.9205 - val_binary_io_u: 0.8524 - lr: 2.5000e-04
# Epoch 94/100
# 3/3 [==============================] - 2s 707ms/step - loss: 0.1273 - accuracy: 0.9477 - binary_io_u: 0.8991 - val_loss: 0.2318 - val_accuracy: 0.9202 - val_binary_io_u: 0.8520 - lr: 2.5000e-04
# Epoch 95/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1390 - accuracy: 0.9436 - binary_io_u: 0.8923 - val_loss: 0.2300 - val_accuracy: 0.9202 - val_binary_io_u: 0.8519 - lr: 2.5000e-04
# Epoch 96/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1341 - accuracy: 0.9450 - binary_io_u: 0.8943 - val_loss: 0.2299 - val_accuracy: 0.9203 - val_binary_io_u: 0.8521 - lr: 2.5000e-04
# Epoch 97/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1395 - accuracy: 0.9415 - binary_io_u: 0.8881 - val_loss: 0.2294 - val_accuracy: 0.9204 - val_binary_io_u: 0.8523 - lr: 2.5000e-04
# Epoch 98/100
# 3/3 [==============================] - 2s 707ms/step - loss: 0.1299 - accuracy: 0.9462 - binary_io_u: 0.8961 - val_loss: 0.2305 - val_accuracy: 0.9199 - val_binary_io_u: 0.8514 - lr: 2.5000e-04
# Epoch 99/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1266 - accuracy: 0.9495 - binary_io_u: 0.9021 - val_loss: 0.2289 - val_accuracy: 0.9201 - val_binary_io_u: 0.8518 - lr: 2.5000e-04
# Epoch 100/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9452 - binary_io_u: 0.8951
# Epoch 100:saving model to ./model_weight/callback_test/test_weight_epoch_100.h5
# 3/3 [==============================] - 10s 4s/step - loss: 0.1342 - accuracy: 0.9452 - binary_io_u: 0.8951 - val_loss: 0.2283 - val_accuracy: 0.9199 - val_binary_io_u: 0.8514 - lr: 2.5000e-04

# %%
model.summary()
